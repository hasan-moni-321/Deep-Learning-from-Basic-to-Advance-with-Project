# %% [markdown]
# ### Vanishing Gradient:
#     Problem:
#         The main problem of vanishing gradient is in backpropagation it change weight very less, that is almost equal to the old weight.

# %%
from IPython.display import Image

# %%
#printing a neural network
Image(filename='/home/hasan/Pictures/a1.png')

# %% [markdown]
# derivative of w11 weight

# %%
#Chain Rule of w11
Image(filename='/home/hasan/Pictures/a2.png')

# %%
#sigmoid function in derivative
Image(filename='/home/hasan/Pictures/a3.png')

# %%
#updating weight using Backpropagation
Image(filename='/home/hasan/Pictures/a4.png')

# %%
#updating weight using Backpropagation
Image(filename='/home/hasan/Pictures/a5.png')
