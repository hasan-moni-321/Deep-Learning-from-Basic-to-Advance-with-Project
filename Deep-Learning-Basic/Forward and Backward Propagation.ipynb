# %%
from IPython.display import Image

# %% [markdown]
# # Forward Propagation

# %% [markdown]
# As the name suggests, the input data is fed in the forward direction through the network. Each hidden layer
# accepts the input data, processes it as per the activation function and passes to the successive layer.

# %% [markdown]
# Preactivation:
#     it is a weighted sum of inputs i.e. the linear transformation of weights w.r.t to inputs available. Based
# on this aggregated sum and activation function the neuron makes a decision whether to pass this information
# further or not.

# %% [markdown]
# Activation:
# the calculated weighted sum of inputs is passed to the activation function. An activation function is a
# mathematical function which adds non-linearity to the network. There are four commonly used and popular
# activation functions — sigmoid, hyperbolic tangent(tanh), ReLU and Softmax.

# %%
Image(filename='/home/hasan/Pictures/aaa.png')

# %% [markdown]
# Process Inside a Neuron:-
#     1. After giving input, this input multiply it self with weight
#     2. After multiplying weight, this result with add bias
#     3. After adding bias, this result will be feeded by the activation function.
#     4. Then this result will transmit to the next layer of the neuron.

# %% [markdown]
# # Backward Propagation

# %% [markdown]
# Back-propagation is the essence of neural net training. It is the practice of fine-tuning the weights of a
# neural net based on the error rate (i.e. loss) obtained in the previous epoch (i.e. iteration). Proper
# tuning of the weights ensures lower error rates, making the model reliable by increasing its generalization.

# %%
#Formula of Weight Updating

# %%
Image(filename='/home/hasan/Pictures/dddd.png')

# %% [markdown]
# this process happen using optimizer. There are lot of optimizer like Gradient Descent Optimizer.and this process will continue for every weight in the neural net.

# %%
#Gradient Descent

# %%
Image(filename='/home/hasan/Pictures/gradient.png')

# %% [markdown]
# Positive Derivative:-
#     When we got to up from one point it is called positive derivative.
#
# Negative Derivative:-
#     When we got to down from one point it is called negative derivative.
#
# When we want of reduce loss, we need negative derivative, after getting negative derivative, we multiply learning rate with negative drivative and we will get a negative result. This negative result multiply with negative sign that means we are gtting a positive value. This positive value will add itself with old weight that means we are increasing weight.
#
# Note: we need to reach into global minimum by decreasing loss, another way to increase learning rate.

# %%
#Counting Loss

# %%
Image(filename='/home/hasan/Pictures/bbbbb.png')

# %%
#Counting Cost

# %%
Image(filename='/home/hasan/Pictures/cost.png')
