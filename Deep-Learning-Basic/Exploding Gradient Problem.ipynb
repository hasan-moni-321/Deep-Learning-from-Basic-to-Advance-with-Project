# %%
### Exploding Gradient:                                                                                                                                                
    Problem:                                                                                                                      
        The main problem of exploding gradient is it changes the weight in backpropagation with very large 
        difference between onld and new weight. For this in gradient descent grapth cost point change from  
        here and there, it never rech into global minimum.
        
        Note:
            Exploding Gradient Problem happen for bias not for sigmoid function.

# %%
from IPython.display import Image

# %%
#lets see an simple ANN 
Image(filename='/home/hasan/Pictures/a6.png')

# %%
Image(filename='/home/hasan/Pictures/a7.png')

# %% [markdown]
# that is a very large value.

# %%
Image(filename='/home/hasan/Pictures/a8.png')

# %%
Image(filename='/home/hasan/Pictures/a9.png')

# %% [markdown]
# This is a very large new weight compered to old weight. For this gradient descent value will jump form here
# and there, but it will never reach into global minimum.
