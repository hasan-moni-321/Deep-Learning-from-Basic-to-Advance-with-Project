# %%
from IPython.display import Image

# %%
Image(filename=('/home/hasan/Pictures/a10.png'))

# %% [markdown]
# Here I droped 50% neuron. From every layer 50% neuron will drop at the time of training time.

# %% [markdown]
# # What Happen Dropout with Test Data?

# %%
When we test our model with test data every neuron will connect with one another(in test data dropout will not
work) and weight will multiply with dropout ratio in every layer like (dropout_ratio * weight)
